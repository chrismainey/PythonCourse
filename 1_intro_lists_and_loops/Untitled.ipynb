# %%
import pyodbc

# %%
conn = pyodbc.connect("DSN=NRLS_Lit_Review")
cursor = conn.cursor()
for row in cursor.tables():
    print row.table_name
# Out:
# BiasTags
# Import
# Include
# Merges
# Standard_bias
# Studies
# Studies_ar20160617
# Studies_arc20160316
# Subject
# Subject2
# SubjectTags
# SubjectTags_arc
# subjectTags_arc20160316
# sysdiagrams
# Type
# trace_xe_action_map
# trace_xe_event_map
# CHECK_CONSTRAINTS
# COLUMN_DOMAIN_USAGE
# COLUMN_PRIVILEGES
# COLUMNS
# CONSTRAINT_COLUMN_USAGE
# CONSTRAINT_TABLE_USAGE
# DOMAIN_CONSTRAINTS
# DOMAINS
# KEY_COLUMN_USAGE
# PARAMETERS
# REFERENTIAL_CONSTRAINTS
# ROUTINE_COLUMNS
# ROUTINES
# SCHEMATA
# SEQUENCES
# TABLE_CONSTRAINTS
# TABLE_PRIVILEGES
# TABLES
# VIEW_COLUMN_USAGE
# VIEW_TABLE_USAGE
# VIEWS
# all_columns
# all_objects
# all_parameters
# all_sql_modules
# all_views
# allocation_units
# assemblies
# assembly_files
# assembly_modules
# assembly_references
# assembly_types
# asymmetric_keys
# availability_databases_cluster
# availability_group_listener_ip_addresses
# availability_group_listeners
# availability_groups
# availability_groups_cluster
# ...

# %%
cursor.execute("SELECT * FROM sys.columns;")
cursor.fetchall()
# Out:
# [(3, u'rsid', 1, 127, 127, 8, 19, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
#  (3, u'rscolid', 2, 56, 56, 4, 10, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
#  (3, u'hbcolid', 3, 56, 56, 4, 10, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
#  (3, u'rcmodified', 4, 127, 127, 8, 19, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
#  (3, u'ti', 5, 56, 56, 4, 10, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
#  (3, u'cid', 6, 56, 56, 4, 10, 0, None, False, False, False, False, False, False, False, False, False, False, False, 0, 0, 0, False, False),
# ...
