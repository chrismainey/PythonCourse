# %% [markdown]
# # Scientific Programming in Python - Dictionaries and Functions

# %% [markdown]
# ###Problem 1. Library, with dictionaries

# %% [markdown]
# We’ll revisit the Problem 3 of Assignment 2, where we had to manipulate some data from a fake
# library.
#
# In this problem, we had the following format for the data:

# %%
[[123456,312314,531337],                     # Student IDS
 ['John Doe',' Jane Miller','Ted Johnson'],  # Student Names
 [1.49,0.00,8.12]]                           # Amounts owed
# Out:
# [[123456, 312314, 531337],
#  ['John Doe', ' Jane Miller', 'Ted Johnson'],
#  [1.49, 0.0, 8.12]]

# %% [markdown]
# >**(a)** Construct a dictionary to store this data, using the student ID (the ﬁrst big number) as the **key**, and the amount owed as the **values**.
#
# > Use the code below to get you started. You can type the key, value pairs into the curly brackets `{ }`.

# %%
student_id_to_amount_owed = {123456: 1.49, 312314: 0.00,531337: 8.12}  # complete this line to include all the student IDs and amounts owed
print student_id_to_amount_owed
# Out:
# {123456: 1.49, 531337: 8.12, 312314: 0.0}

# %% [markdown]
# > **(b)** Use this dictionary to find out how much money the student with id `531337` owes.
#
# > You should use square brackets `[ ]` to index into your dictionary.

# %%
print(student_id_to_amount_owed[531337])
# Out:
# 8.12

# %% [markdown]
# > Try also finding out how much 123456 owes. What about newly enrolled student 999888?

# %%
amount_owed_by_531337 = student_id_to_amount_owed
print (amount_owed_by_531337)

print(student_id_to_amount_owed[999888])
# Out:
# {123456: 1.49, 531337: 8.12, 312314: 0.0}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0fe73925c4d3> in <module>()
#       2 print (amount_owed_by_531337)
#       3
# ----> 4 print(student_id_to_amount_owed[999888])
#
# KeyError: 999888

# %% [markdown]
# > **(c)** Create another dictionary which maps the name of the student to its student id.  This time, instead of typing the values in by hand, fill in this dictionary by looping over the list `student_names_and_ids` given below:

# %%
student_names_and_ids = [('John Doe', 123456), ('Jane Miller', 312314), ('Ted Johnson', 531337)]

studentname_to_id = {}  # initialise empty dictionary

for name, sid in student_names_and_ids:
    studentname_to_id[name] = sid

print studentname_to_id
# desired output : {'Jane Miller': 312314, 'John Doe': 123456, 'Ted Johnson': 531337}
# Out:
# {'Jane Miller': 312314, 'Ted Johnson': 531337, 'John Doe': 123456}

# %% [markdown]
# > **(c)** Print how much money 'John Doe' owes the library, using both of your dictionaries.
#
# >  *(Hint: First find out John Doe's student ID, then use this to find out how much he owes)*

# %%
John_doe_balance = student_id_to_amount_owed[studentname_to_id['John Doe']]
print(John_doe_balance)
# Out:
# 1.49

# %% [markdown]
# > **(d)** Create the list of the names of students owing more than £1.0 to the library.
#
# > *(Hint: If it is easier, first make a list of all the student IDs which owe more than £1.0 Then adapt the code to create a list of names instead).*

# %%
bad_students = [] 

for sid, val in student_id_to_amount_owed.items():
    if val > 1.0:
        for nm, ssid in student_names_and_ids:
            if sid == ssid:
                bad_students.append(nm)

print (bad_students)
# Out:
# ['John Doe', 'Ted Johnson']

# %% [markdown]
# ###Problem 2. Counting words

# %% [markdown]
# >**(a)** In this problem we’ll use the text of Alice in Wonderland to construct dictionaries counting the
# number of times particular words and pairs of words appear.

# %%
import urllib2
URL = "http://www.gutenberg.org/files/11/11.txt"
f = urllib2.urlopen(URL)
open("alice.txt","w").write(f.read())

# %% [markdown]
# This will create a new file called "alice.txt"

# %% [markdown]
# >**(b)** We'll process alice.txt in loops like this:

# %%
f = open("alice.txt", "r")

words = {}

for line in f.readlines():
     for word in line.strip().split():
        if word not in words:
            words[word] = 1
        else:
        #elif word in words:
            words[word] = words[word]+1


print[words]
# Out:
# [{"figure!'": 1, 'four': 6, 'hanging': 3, 'ringlets': 1, "story!'": 2, 'Foundation': 14, 'IX.': 1, "'Shall": 1, 'dear!"': 1, "dear!'": 3, 'wood,': 1, 'wood.': 3, 'advice,': 1, 'screaming': 1, 'prize': 1, 'wooden': 1, 'further:': 1, 'persisted': 1, 'her.': 13, 'tired': 7, "ears--'": 1, 'BEG': 1, 'chin:': 1, 'her;': 3, 'her:': 5, 'second': 6, 'audibly.': 1, 'chin.': 2, "'You": 30, 'accessed,': 1, 'increasing': 1, 'is--"The': 1, "impertinent,'": 1, 'glass;': 1, "so.'": 1, 'reasons.': 1, 'here': 14, 'fire,': 3, "'THAT": 2, 'glass.': 1, 'glass,': 2, 'hers': 3, 'shriek': 3, 'finger;': 1, 'pieces.': 1, 'barrowful': 2, 'NOT': 7, 'golden': 7, 'owed': 1, 'words:--': 2, 'then--always': 1, 'replace': 1, 'brought': 3, "Caterpillar's": 1, "sea,'": 1, 'spoke': 4, 'Indeed,': 1, 'until': 4, 'dry,': 1, 'paperwork': 1, 'hurt': 2, 'glass': 4, '90': 2, 'hold': 7, 'sorry': 1, 'liability,': 1, 'laughter.': 1, '"THEY': 1, 'NOTICE': 1, 'unjust': 1, 'organized': 1, 'shore.': 1, 'shore,': 2, "liked.'": 1, "that.'": 3, 'want': 9, 'around,': 1, "court!'": 1, 'STRICT': 1, 'complaining': 1, 'damage': 1, 'door--I': 1, 'how': 41, 'hot': 4, 'youth,': 3, 'win,': 1, 'A': 8, 'somebody,': 1, 'cautiously:': 1, "Mouse's": 1, 'wrong': 2, 'types': 1, "creatures,'": 1, 'wink': 2, 'salmon,': 1, 'Mabel': 1, 'thimble,': 2, 'sharply;': 1, 'Even': 1, 'dreamed': 1, 'effect,': 1, 'information:': 1, 'hair."': 1, 'sharply.': 1, 'sharply,': 1, 'effect:': 1, 'bread-and-butter': 2, 'His': 1, 'bringing': 3, 'fix': 2, "'Nobody": 2, 'ready?': 1, 'copying': 2, 'slate': 1, "'creatures,'": 1, 'HIGH': 1, 'interrupt': 1, "''Tis": 2, 'strings:': 1, "'All": 2, 'Mouse': 17, 'financial': 1, 'telescope': 1, 'series': 1, "'Tell": 1, "'Mouse": 1, 'array': 1, "lessons?'": 1, 'encourage': 1, 'Rabbit': 29, "temper,'": 1, 'stamping': 2, 'occasionally;': 1, 'mallets': 1, 'enormous': 1, 'ate': 1, 'ANYTHING': 1, 'shelves': 1, 'moment': 21, "house!'": 1, 'nasty,': 1, 'cushion;': 1, "what?'": 2, "'Fetch": 1, 'Lacie,': 1, 'Gutenberg"),': 1, 'wash': 2, 'cushion,': 1, "'what's": 1, 'her,': 18, 'sobs,': 1, 'sure!': 1, 'sobs.': 1, 'master': 2, 'legs': 3, 'sure,': 2, 'easy.': 1, 'listen': 4, 'was:': 2, 'was)': 1, 'was,': 14, 'was!': 1, 'positively': 1, 'elegant': 1, "confusing.'": 1, 'Carroll': 4, "prison,'": 1, 'shower': 2, 'exclaimed': 4, 'fish)--and': 1, 'feeling': 6, 'old,': 2, 'heads.': 1, 'well,': 1, 'well.': 2, 'well!': 1, 'me?': 1, 'Then': 9, '"Turtle': 1, 'eagerly': 3, 'doors': 2, 'long;': 1, 'shall': 23, 'doze;': 1, 'TWO--"': 1, 'fees,': 1, 'fees.': 1, 'mouth': 7, "size,'": 1, 'long,': 1, 'difficulties,': 1, 'stupid': 1, 'door,': 9, 'door.': 2, "on!'": 6, 'scream': 1, 'door;': 1, 'door:': 1, 'saying': 11, "too.'": 1, 'sneezing,': 1, 'sneezing.': 1, 'terror.': 1, 'rope--Will': 1, 'lessons': 4, 'busy': 1, 'rich': 1, 'Northumbria,': 1, 'green,': 1, 'them--and': 2, "haven't,'": 1, "'no": 1, 'plate': 2, "lady,'": 1, 'listened,': 1, 'pocket': 1, 'altogether': 1, "window!'": 1, 'Soup,"': 1, "'Dinah'll": 1, 'nicely': 2, "lower,'": 1, 'them:': 1, 'SEND': 1, '#11]': 1, 'them.': 2, 'them,': 21, "'I--I": 1, "Cat's": 2, 'blew': 2, 'fair': 1, "be,'": 3, 'result': 1, 'best': 7, "us,'": 1, 'Lory,': 3, 'Lory.': 1, 'preserve': 1, 'claws': 1, 'interrupting': 2, "'Stolen!'": 1, 'camomile': 1, 'twinkling': 3, 'extent': 1, 'seriously,': 1, "do!'": 3, 'pity': 1, 'accident': 1, 'reported': 1, 'country': 3, 'adventures': 2, 'ring,': 2, 'MILLENNIUM': 1, 'asked': 8, 'directly,': 1, 'Forty-two.': 1, '25,': 1, 'doubt,': 2, "'until": 1, 'doubt:': 1, 'skirt,': 1, 'quarrelling': 2, 'apples,': 2, 'much': 41, "extremely--'": 1, 'dry': 7, 'life': 2, 'follow,': 1, "say?'": 1, "so,'": 5, "bit.'": 1, "first!'": 1, 'child': 3, 'doth': 2, 'Gryphon,': 14, 'Gryphon.': 15, 'angry.': 1, 'angry,': 1, 'tried.': 1, 'Gryphon;': 1, 'holding,': 1, 'remembering': 1, 'played': 1, 'desperately:': 1, 'said:': 3, 'said;': 2, 'death."\'': 1, 'stiff.': 1, "'My": 2, '\'"Miss': 1, 'said,': 26, 'said.': 4, '(WITH': 1, 'damaged': 1, 'things': 21, 'format': 4,  ...

# %% [raw]
# >Modify this code so that it creates a new dictionary called words at (1).<br> For (2), if a word
# is not already in the dictionary words, then add it to the dictionary with a value of 1. <br>If a
# word is already in the dictionary words, then increment the value stored in the dictionary
# by one.<br>
#
# >At location (3), print out the dictionary words.

# %% [markdown]
# >**(b)** How many times does the word “the” appear? What about the word “The”?

# %%
print(words['the'])
print(words['The'])
# Out:
# 1664
# 100

# %% [markdown]
# >**(d)** Modify the code so words are counted independent of whether they are made of upper or
# lower case letters. i.e., “the”, “The” and “tHE” are all treated as the same word.

# %%
f = open("alice.txt", "r")

words = {}

for line in f.readlines():
     for word in line.strip().split():
        if word.lower() not in words:
            words[word.lower()] = 1
        elif word.lower() in words:
            words[word.lower()] = words[word.lower()]+1


print[words]

# %% [markdown]
# >**(e)** Repeat the previous exercise, but instead of counting the number of times a word appears,
# count the number of times pairs of words appear. You might ﬁnd it useful to store the
# previous word in a variable.

# %%
f = open("alice.txt", "r")

words = {}
prev_wd = ''

for line in f.readlines():
     for word in line.strip().split():
        if word.lower() + ' ' + prev_wd.lower() not in words:
            words[word.lower() + ' ' + prev_wd.lower()] = 1
        elif word.lower() + ' ' + prev_wd.lower() in words:
            words[word.lower() + ' ' + prev_wd.lower()] = words[word.lower() + ' ' + prev_wd.lower()]+1
        prev_wd = word

print[words]
# Out:
# [{'my dinah': 1, "generally 'it's": 1, 'but character,': 1, 'the displaying': 1, "muttered it?'": 1, 'complying without': 1, "think can't": 1, 'uncomfortable. very': 1, 'eaglet, an': 1, 'very get': 1, "nothing 'you're": 1, 'a croquet-ground': 1, 'alice plate.': 1, 'tasted never': 1, "said caucus-race?'": 1, 'you see': 2, 'be stuff?': 1, 'hunting after': 1, 'first--they together': 1, 'how think': 1, 'any it': 1, 'puzzling on': 1, 'opened, house': 1, 'pink with': 1, 'settled it': 1, 'confusion such': 1, 'would you': 2, 'he all:': 1, 'fact, in': 2, 'to knew)': 1, 'any in': 5, 'implied certain': 1, 'about more': 1, 'her forgetting': 1, 'or come,': 1, "down,' sit": 1, 'without allow': 1, 'the protect': 2, 'herself find': 2, 'sky! the': 1, 'the persisted': 1, 'usually you': 1, "'but sight:": 1, 'to found': 1, "manage i'll": 1, 'turtle--we old': 1, 'links active': 2, 'was door': 1, 'down got': 1, 'http://pglaf.org/donate visit:': 1, '\'ugh!\' northumbria--"\'': 1, 'sit but': 1, 'under distributor': 1, 'brush, his': 1, 'this squeaked.': 1, 'law: to': 1, 'confusion, in': 1, 'the finished,': 1, 'spite in': 1, 'jar the': 1, 'keeping for': 1, 'infringement, property': 1, "'--for like,": 1, 'sleep its': 1, 'its also': 1, "at 'well,": 1, 'alice off.': 1, "house!' the": 1, 'at down': 5, 'and king': 3, 'came all': 2, 'order creatures': 1, 'as see,': 3, 'pigeon the': 5, 'had water': 1, "know didn't": 4, 'have pigs': 1, 'was, said': 1, 'her, for': 1, 'project distributed': 1, 'without court,': 1, 'well. as': 1, "think 'just": 1, "honour!' yer": 2, 'that fees,': 1, 'question this': 1, 'of search': 1, 'me baked': 1, "to-day?' queen": 1, 'and soup,': 1, 'do changed,': 1, 'running began': 2, 'darkness the': 1, 'access provide': 1, "'are tone.": 1, 'without once': 1, 'a indeed': 1, 'over was': 2, 'added then': 1, 'meekly hare': 1, 'though you,': 1, 'very finger': 1, "shouldn't 'you": 1, 'up themselves': 1, "'is wood,": 1, 'turned it': 2, 'the taken': 1, "dormouse,' the": 1, 'to severely': 1, 'rather her': 1, 'blows the': 1, 'on sister': 1, 'whistle to': 1, 'breathe "i': 1, 'turn-up very': 1, 'delight, of': 2, 'face his': 1, 'five. said': 1, 'whiskers! and': 1, 'ways extraordinary': 1, 'that minutes': 1, "the 'why": 1, 'her reminding': 1, 'little the': 18, "don't and": 1, 'ten the': 1, 'includes site': 1, 'has which': 1, 'something know': 1, 'and houses,': 1, 'high. inches': 1, "first.' are,": 1, 'them telling': 1, 'then anything;': 1, 'copying, downloading,': 1, 'she cat,': 1, "here.' more": 1, "remedies--' energetic": 1, 'friends their': 1, "cleared you've": 1, 'ordered. had': 1, 'gave they': 2, 'mad. not': 1, "me.' and": 1, 'in heard': 1, 'finding and': 1, 'while spoon:': 1, 'off, ran': 1, 'alone alice': 1, 'itself rearing': 1, 'but absurd,': 1, 'then that:': 1, 'all through': 1, 'shaped all': 1, 'face--and her': 1, 'damages, for': 1, 'jury, the': 4, 'her, like': 1, 'for messages': 1, 'quite making': 2, "why 'but": 2, 'clearer be': 1, 'you, to': 1, 'opportunity good': 3, "time,' the": 1, "said do?'": 1, 'of shriek': 2, 'sneezing. for': 1, 'guard to': 1, "alice's to": 2, 'such and': 1, 'on medium': 1, 'improve crocodile': 1, 'across ran': 1, 'modified be': 1, 'compliance. of': 1, 'at who': 1, 'got she': 8, 'that works': 2, 'copy a': 2, "porpoise.' a": 1, 'to coming': 1, 'to meant': 1, 'nonproprietary up,': 1, 'and states': 1, "as wonder?'": 1, "'what glass.": 1, 'go can': 1, 'had what': 1, 'give not': 1, 'resting cushion,': 1, 'about now': 2, 'do, could': 1, 'once seaside': 1, 'yet--and rabbit-hole--and': 1, "doesn't 'it": 1, "'i son,": 1, "'and becoming.": 1, 'used got': 1, 'for beg': 1, 'ledge little': 1, 'in slipped': 1, 'time, to': 1, "'there's voice.": 1, 'financial and': 1, "'of is?'": 1, 'watching after': 1, "business!' his": 1, 'seemed it': 2, 'court," the': 1, 'subscribe to': 1, 'that lately,': 1, 'the ix.': 1, 'off, be': 3, 'remark, last': 1, 'little a': 54, "'so sky-rocket!'": 1, "wasn't 'it": 1, "dormouse 'the": 1, 'little of': 6, 'hers ...

# %% [markdown]
# >**(f)** What are the most common words and pairs of words in Alice in Wonderland?<br> You might find the *sorted* function or the *sort* function for lists to be useful.

# %%
# hint: example of how you use sorted
x = [1,4,2,7,5,6,3]
print x
#print sorted(x),type(sorted(x)) # outputs a list
#print sort(x),type(sort(x))  # outputs a numpy.ndarray

#print sorted([words]) , type(sorted([words]))

sorted( ((wd,ct) for ct,wd in words.iteritems()), reverse=True)  #  the iteritems combined with for and reverse order of wd/ct means it will sort in the value rather than key.
# Out:
# [1, 4, 2, 7, 5, 6, 3]
# [(207, 'the said'),
#  (154, 'the of'),
#  (101, 'a in'),
#  (92, 'the in'),
#  (84, 'the to'),
#  (80, 'the and'),
#  (63, 'the at'),
#  (60, 'she as'),
#  (57, 'had she'),
#  (57, '* *'),
#  (55, 'was it'),
#  (54, 'little a'),
#  (54, 'gutenberg-tm project'),
#  (53, 'mock the'),
#  (51, 'was she'),
#  (50, 'the with'),
#  (49, 'she and'),
#  (49, 'be to'),
#  (39, 'to said'),
#  (38, 'alice, said'),
#  (37, 'the on'),
#  (37, 'of out'),
#  (34, 'was there'),
#  (33, 'turtle mock'),
#  (33, 'alice. said'),
#  (32, 'she that'),
#  (31, 'queen the'),
#  (31, 'a was'),
#  (30, 'the all'),
#  (29, 'the by'),
#  (29, 'she so'),
#  (29, 'project the'),
#  (29, 'march the'),
#  (28, 'went she'),
#  (28, 'said she'),
#  (28, 'king the'),
#  (27, 'this of'),
#  (27, 'not did'),
#  (27, 'alice said'),
#  (27, 'a with'),
#  (27, 'a such'),
#  (26, 'you if'),
#  (25, 'very a'),
#  (25, 'herself, to'),
#  (24, 'then and'),
#  (24, 'the into'),
#  (24, 'a of'),
#  (23, 'the for'),
#  (23, 'see to'),
#  (23, 'on went'),
#  (23, 'it that'),
#  (22, 'white the'),
#  (22, 'she but'),
#  (22, 'of one'),
#  (22, 'hatter the'),
#  (22, 'gutenberg project'),
#  (21, 'gryphon the'),
#  (20, 'to seemed'),
#  (20, 'same the'),
#  (20, 'large a'),
#  (20, 'dormouse the'),
#  (20, 'and up'),
#  (19, 'was and'),
#  (19, 'the was'),
#  (19, 'it as'),
#  (19, 'could she'),
#  (18, 'well as'),
#  (18, 'the as'),
#  (18, 'she when'),
#  (18, 'other the'),
#  (18, 'on, went'),
#  (18, 'mouse the'),
#  (18, 'little the'),
#  (18, 'get to'),
#  (18, 'electronic gutenberg-tm'),
#  (18, 'be must'),
#  (17, 'was alice'),
#  (17, 'rabbit the'),
#  (17, 'queen, the'),
#  (17, 'of terms'),
#  (17, 'not could'),
#  (17, 'her to'),
#  (17, 'her of'),
#  (17, 'be would'),
#  (17, 'at looked'),
#  (17, 'a like'),
#  (17, 'a for'),
#  (16, 'hare march'),
#  (16, 'great a'),
#  (16, "don't 'i"),
#  (16, 'been had'),
#  (16, 'a and'),
#  (15, 'say to'),
#  (15, 'of sort'),
#  (15, 'king, the'),
#  (15, 'her in'),
#  (15, 'had it'),
#  (15, 'gryphon. the'),
#  (15, 'first the'),
#  (15, 'duchess the'),
#  (15, 'alice and'),
#  (15, 'a into'),
#  (14, 'were they'),
#  (14, 'the that'),
#  (14, 'the but'),
#  (14, "said it,'"),
#  (14, 'good a'),
#  (14, "don't i"),
#  (14, 'as just'),
#  (14, 'and it,'),
#  (14, 'a be'),
#  (13, 'whole the'),
#  (13, 'the like'),
#  (13, 'of end'),
#  (13, 'literary gutenberg'),
#  (13, 'if as'),
#  (13, 'i if'),
#  (13, 'he as'),
#  (13, 'hatter. the'),
#  (13, 'gryphon, the'),
#  (13, 'go to'),
#  (13, 'find to'),
#  (13, 'felt she'),
#  (13, 'did she'),
#  (13, 'archive literary'),
#  (13, 'and again,'),
#  (12, 'would it'),
#  (12, 'to ought'),
#  (12, 'to had'),
#  (12, 'to going'),
#  (12, 'to back'),
#  (12, 'the is'),
#  (12, 'terms the'),
#  (12, 'some for'),
#  (12, 'should i'),
#  (12, 'shall i'),
#  (12, 'rabbit white'),
#  (12, 'or minute'),
#  (12, 'not was'),
#  (12, 'next the'),
#  (12, 'make to'),
#  (12, 'long a'),
#  (12, 'last at'),
#  (12, 'king. the'),
#  (12, 'do to'),
#  (12, 'caterpillar. the'),
#  (12, 'began and'),
#  (11, 'you do'),
#  (11, 'what know'),
#  (11, 'went and'),
#  (11, 'to used'),
#  (11, 'to it'),
#  (11, 'the from'),
#  (11, 'the about'),
#  (11, 'right the'),
#  (11, 'queen. the'),
#  (11, 'one with'),
#  (11, 'not do'),
#  (11, 'minute a'),
#  (11, 'may you'),
#  (11, 'looked and'),
#  (11, 'it but'),
#  (11, 'in it'),
#  (11, 'i when'),
#  (11, 'herself to'),
#  (11, 'heard she'),
#  (11, 'head her'),
#  (11, 'have to'),
#  (11, 'hare. march'),
#  (11, 'going was'),
#  (11, 'found she'),
#  (11, 'door the'),
#  (11, 'could alice'),
#  (11, 'all they'),
#  (11, 'all at'),
#  (11, 'all and'),
#  (10, 'you that'),
#  (10, 'works electronic'),
#  (10, "won't you,"),
#  (10, 'very was'),
#  (10, 'to turning'),
#  (10, 'to like'),
#  (10, 'thought alice'),
#  (10, 'them of'),
#  (10, 'the when'),
#  (10, 'the under'),
#  (10, 'the took'),
#  (10, 'she till'),
#  (10, 'she for'),
#  (10, 'not had'),
#  (10, 'i what'),
#  (10, 'he and'),
#  (10, 'have must'),
#  (10, 'hatter, the'),
#  (10, 'end the'),
#  (10, 'caterpillar the'),
#  (10, "can't i"),
#  (10, 'can i'),
#  (10, 'began she'),
#  (10, 'as well'),
#  (10, 'an in'),
#  (10, 'alice, thought'),
#  (10, 'a had'),
#  (9, 'you, will'),
#  (9, 'words the'),
#  (9, 'were there'),
#  (9, 'was who'),
#  (9, 'use no'),
#  (9, 'united the'),
#  (9, 'turtle. mock'),
#  (9, 'tried she'),
#  (9, 'to tried'),
#  (9, 'time this'),
#  (9, 'time the'),
#  (9, 'thought she'),
#  (9, 'they when'),
#  (9, 'the near'),
#  (9, 'the join'),
#  (9, 'the down'),
#  (9, 'she if'),
#  (9, 'said alice'),
#  (9, 'project of'),
#  (9, 'poor the'),
#  (9, 'of use'),
#  (9, 'never had'),
#  (9, 'looked she'),
#  (9, "know.' you"),
#  (9, 'know you'),
#  (9, 'it if'),
#  (9, 'in was'),
#  (9, 'his with'),
#  (9, 'her at'),
#  (9, 'had they'),
#  (9, 'had alice'),
#  (9, 'full the'),
#  (9, 'foundation archive'),
#  (9, 'dodo the'),
#  (9, 'did alice'),
#  (9, 'any of'),
#  (9, 'alice; said'),
#  (9, 'alice, to'),
#  (9, 'a to'),
#  (9, 'a after'),
#  (8, "you, won't"),
#  (8, 'you to'),
#  (8, "you 'if"),
#  (8, 'work the'),
#  (8, 'work electronic'),
#  (8, "with 'off"),
#  (8, 'when and'),
#  (8, 'way the'),
#  (8, 'was this'),
#  (8, 'use the'),
#  (8, 'turtle, mock'),
#  (8, 'top the'),
#  (8, 'to up'),
#  (8, 'to trying'),
#  (8, 'to how'),
#  (8, 'to got'),
#  (8, 'to began'),
#  (8, 'to agree'),
#  (8, 'to access'),
#  (8, 'think i'),
#  (8, 'they and'),
#  (8, 'their on'),
#  (8, 'the while'),
#  (8, 'the through'),
#  (8, 'the round'),
#  (8, 'the cried'),
#  (8, 'the among'),
#  (8, 'she then'),
#  (8, 'see, you'),
#  (8, 'said he'),
#  (8, 'said and'),
#  (8, 'quite was'),
#  (8, 'not would'),
#  (8, 'no was'),
#  (8, "no there's"),
#  (8, 'must you'),
#  (8, 'might it'),
#  (8, 'looked alice'),
#  (8, 'little poor'),
#  (8, 'know i'),
#  (8, "know don't"),
#  (8, 'its with'),
#  (8, 'its of'),
#  (8, 'it thought'),
#  (8, 'it of'),
#  (8, 'is it'),
#  (8, 'in forth'),
#  (8, 'her with'),
#  (8, 'had who'),
#  (8, 'got she'),
#  (8, 'forth set'),
#  (8, 'duchess, the'),
#  (8, 'down sat'),
#  (8, 'domain public'),
#  (8, "course 'of"),
#  (8, 'cook the'),
#  (8, 'can you'),
#  (8, 'came she'),
#  (8, 'been have'),
#  (8, 'and them,'),
#  (8, 'and alice,'),
#  (8, 'all were'),
#  (8, 'alice to'),
#  (8, 'agreement this'),
#  (8, 'a on'),
#  (8, 'a not'),
#  (8, 'a is'),
#  (7, 'you what'),
#  (7, 'you tell'),
#  (7, 'would she'),
#  (7, 'work this'),
#  (7, 'what wonder'),
#  (7, 'what see'),
#  (7, 'was i'),
#  (7, 'was he'),
#  (7, 'to you'),
#  (7, 'to went'),
#  (7, 'to time'),
#  (7, 'to set'),
#  (7, 'to seem'),
#  (7, 'to saying'),
#  (7, 'to beginning'),
#  (7, 'to alice'),
#  (7, 'three the'),
#  (7, 'this by'),
#  (7, 'this and'),
#  (7, 'they so'),
#  (7, 'they as'),
#  (7, 'the added'),
#  (7, 'that of'),
#  (7, 'so was'),
#  (7, 'she before'),
#  (7, 'rest the'),
#  (7, 'rabbit, white'),
#  (7, "queen's the"),
#  (7, 'project full'),
#  (7, 'out make'),
#  (7, 'once at'),
#  (7, 'on down'),
#  (7, 'of way'),
#  (7, 'of top'),
#  (7, 'of tone'),
#  (7, 'of some'),
#  (7, 'of copies'),
#  (7, "not i'm"),
#  (7, 'no be'),
#  (7, "never 'i"),
#  (7, 'much very'),
#  (7, 'much so'),
#  (7, 'mouse, the'),
#  (7, 'moment the'),
#  (7, 'me let'),
#  (7, "majesty,' your"),
#  (7, 'knave the'),
#  (7, 'it and'),
#  (7, 'into up'),
#  (7, 'in said'),
#  (7, 'in and'),
#  (7, 'in about'),
#  (7, 'i wish'),
#  (7, 'i think'),
#  (7, 'i but'),
#  (7, 'his of'),
#  (7, "hadn't i"),
#  (7, 'had and'),
#  (7, 'do you'),
#  (7, 'cat the'),
#  (7, 'best the'),
#  (7, 'be will'),
#  (7, 'at looking'),
#  (7, 'at look'),
#  (7, 'as it'),
#  (7, 'as and,'),
#  (7, 'are you'),
#  (7, "are 'you"),
#  (7, 'any at'),
#  (7, 'another in'),
#  (7, 'an with'),
#  (7, 'all in'),
#  (7, 'alice. thought'),
#  (7, 'a upon'),
#  (7, 'a quite'),
#  (7, 'a as'),
#  (6, 'your beg'),
#  (6, 'you did'),
#  (6, 'you as'),
#  (6, 'would they'),
#  (6, 'work to'),
#  (6, 'wonder i'),
#  (6, 'wish i'),
#  (6, 'will you,'),
#  (6, 'who alice,'),
#  (6, 'which on'),
#  (6, 'were you'),
#  (6, 'went he'),
#  (6, 'was which'),
#  (6, 'very and'),
#  (6, 'up got'),
#  (6, 'two, or'),
#  (6, 'tone a'),
#  (6, 'to want'),
#  (6, 'to ready'),
#  (6, 'to out'),
#  (6, 'to have'),
#  (6, 'to close'),
#  (6, 'time some'),
#  (6, 'this with'),
#  (6, 'this at'),
#  (6, 'think to'),
#  (6, 'thing little'),
#  (6, 'they that'),
#  (6, 'the which'),
#  (6, 'the up'),
#  (6, 'the try'),
#  (6, 'the then'),
#  (6, 'the over'),
#  (6, "that!' like"),
#  (6, 'that felt'),
#  (6, 'that and'),
#  (6, 'than more'),
#  (6, 'tell to'),
#  (6, 'soon very'),
#  (6, 'soon as'),
#  (6, 'sitting was'),
#  (6, 'she while'),
#  (6, 'she time'),
#  (6, 'she however,'),
#  (6, 'she how'),
#  (6, 'said, she'),
#  (6, 'replied alice'),
#  (6, 'pool the'),
#  (6, 'paragraph in'),
#  (6, 'on sitting'),
#  (6, 'of side'),
#  (6, 'of number'),
#  (6, 'of moral'),
#  (6, 'must i'),
#  (6, 'moral the'),
#  (6, 'low a'),
#  (6, 'looking was'),
#  (6, 'look to'),
#  (6, 'little of'),
#  (6, 'like not'),
#  (6, 'license gutenberg-tm'),
#  (6, 'last the'),
#  (6, 'know. you'),
#  (6, "know,' you"),
#  (6, 'just was'),
#  (6, 'jury the'),
#  (6, 'it see'),
#  (6, 'in works'),
#  (6, 'in use'),
#  (6, 'in up'),
#  (6, 'in on'),
#  (6, 'in alice'),
#  (6, 'in adventures'),
#  (6, 'i and'),
#  (6, 'i am'),
#  (6, 'how and'),
#  (6, 'house the'),
#  (6, 'herself. to'),
#  (6, 'herself found'),
#  (6, 'her, to'),
#  (6, 'her all'),
#  (6, 'he if'),
#  (6, 'have you'),
#  (6, 'had that'),
#  (6, 'had he'),
#  (6, 'great the'),
#  (6, "got i've"),
#  (6, 'few a'),
#  (6, 'dormouse, the'),
#  (6, 'door, the'),
#  (6, "doesn't it"),
#  (6, 'deal good'),
#  (6, 'curious a'),
#  (6, 'could, she'),
#  (6, 'could i'),
#  (6, 'copyright the'),
#  (6, 'come to'),
#  (6, 'cat, the'),
#  (6, 'begin to'),
#  (6, 'baby the'),
#  (6, 'as soon'),
#  (6, 'as and'),
#  (6, 'as alice,'),
#  (6, 'any or'),
#  (6, 'and now'),
#  (6, 'and fan'),
#  (6, 'alice: said'),
#  (6, 'alice, poor'),
#  (6, 'agreement, this'),
#  (6, "adventures alice's"),
#  (6, 'a what'),
#  (6, "a 'what"),
#  (5, 'your please'),
#  (5, 'your of'),
#  (5, 'you wish'),
#  (5, 'you have'),
#  (5, 'you are'),
#  (5, 'you -'),
#  (5, 'with do'),
#  (5, 'with comply'),
#  (5, "wish 'i"),
#  (5, 'window, the'),
#  (5, 'went alice'),
#  (5, 'was that'),
#  (5, "was 'it"),
#  (5, 'walked she'),
#  (5, 'very so'),
#  (5, 'upon came'),
#  (5, 'two or'),
#  (5, 'trees the'),
#  (5, 'too was'),
#  (5, 'to what'),
#  (5, 'to thought'),
#  (5, 'to not'),
#  (5, 'to i'),
#  (5, 'to down'),
#  (5, 'to as'),
#  (5, 'thought, she'),
#  (5, 'this in'),
#  (5, 'thing same'),
#  (5, 'they did'),
#  (5, 'they but'),
#  (5, 'there as'),
#  (5, 'there and'),
#  (5, 'their in'),
#  (5, 'the shouted'),
#  (5, 'the out'),
#  (5, 'the off'),
#  (5, 'the last'),
#  (5, 'the here'),
#  (5, 'the heard'),
#  (5, 'the hear'),
#  (5, "the 'it's"),
#  (5, 'that was,'),
#  (5, 'that so'),
#  (5, 'that out'),
#  (5, 'that in'),
#  (5, 'that find'),
#  (5, 'such in'),
#  (5, 'soldiers the'),
#  (5, "should 'i"),
#  (5, 'she this,'),
#  (5, 'set she'),
#  (5, 'said, and'),
#  (5, "said that,'"),
#  (5, "said me,'"),
#  (5, 'said king'),
#  (5, "said indeed!'"),
#  (5, 'roof the'),
#  (5, 'remembered she'),
#  (5, 'reason the'),
#  (5, 'ran she'),
#  (5, 'put to'),
#  (5, 'project a'),
#  (5, 'pigeon the'),
#  (5, 'own her'),
#  (5, 'out made'),
#  (5, 'out it'),
#  (5, 'out called'),
#  (5, 'other, the'),
#  (5, 'other or'),
#  (5, 'other any'),
#  (5, 'one no'),
#  (5, 'once, at'),
#  (5, 'on. went'),
#  (5, 'on put'),
#  (5, 'on go'),
#  (5, 'old an'),
#  (5, 'off left'),
#  (5, 'of voice'),
#  (5, 'of tired'),
#  (5, 'of think'),
#  (5, 'of rest'),
#  (5, 'of pair'),
#  (5, 'of kind'),
#  (5, 'of distribution'),
#  (5, 'now was'),
#  (5, 'no have'),
#  (5, 'no had'),
#  (5, 'never i'),
#  (5, 'name the'),
#  (5, 'my in'),
#  (5, 'must it'),
#  (5, "must 'i"),
#  (5, 'much as'),
#  (5, 'makes that'),
#  (5, 'made she'),
#  (5, 'like should'),
#  (5, 'leave to'),
#  (5, 'last, at'),
#  (5, 'know, you'),
#  (5, 'kid white'),
#  (5, 'just had'),
#  (5, 'its into'),
#  (5, 'it, about'),
#  (5, 'it what'),
#  (5, 'it put'),
#  (5, 'it on'),
#  (5, 'it for'),
#  (5, 'is work'),
#  (5, "is 'what"),
#  (5, 'in work'),
#  (5, 'in meaning'),
#  (5, 'in herself'),
#  (5, 'if see'),
#  (5, 'i as'),
#  (5, "i 'well,"),
#  (5, "i 'but"),
#  (5, 'house, the'),
#  (5, 'his on'),
#  (5, 'his in'),
#  (5, 'her on'),
#  (5, 'her made'),
#  (5, 'her into'),
#  (5, 'her about'),
#  (5, 'hearts, of'),
#  (5, 'hear to'),
#  (5, 'have would'),
#  (5, 'have i'),
#  (5, 'hatter: the'),
#  (5, 'grow to'),
#  (5, 'great of'),
#  (5, 'got had'),
#  (5, 'golden little'),
#  (5, 'glad very'),
#  (5, 'foundation the'),
#  (5, 'found and'),
#  (5, 'for looking'),
#  (5, 'felt alice'),
#  (5, 'fan the'),
#  (5, 'ebook this'),
#  (5, 'eat to'),
#  (5, "don't you"),
#  (5, 'do can'),
#  (5, 'dance. the'),
#  (5, 'court, the'),
#  (5, 'could you'),
#  (5, 'could not,'),
#  (5, 'cat. the'),
#  (5, "can't you"),
#  (5, 'beginning was'),
#  (5, 'began alice'),
#  (5, 'be should'),
#  (5, 'at in'),
#  (5, 'at down'),
#  (5, 'ask to'),
#  (5, 'as long'),
#  (5, 'any in'),
#  (5, 'and up,'),
#  (5, 'and off,'),
#  (5, 'and herself,'),
#  (5, 'and down'),
#  (5, 'an was'),
#  (5, 'am i'),
#  (5, 'all with'),
#  (5, 'all was'),
#  (5, 'alice; thought'),
#  (5, 'alice that'),
#  (5, 'alice so'),
#  (5, 'about talk'),
#  (5, 'about information'),
#  (5, 'a without'),
#  (5, 'a or'),
#  (5, 'a it'),
#  (5, 'a heard'),
#  (5, "a 'it's"),
#  (4, "you?' are"),
#  (4, 'you yet'),
#  (4, 'you when'),
#  (4, 'you way'),
#  (4, 'you think'),
#  (4, 'you make'),
#  (4, 'you it,'),
#  (4, "you 'would"),
#  (4, "you 'then"),
#  (4, "you 'do"),
#  (4, 'yet and'),
#  (4, "wouldn't you"),
#  (4, 'would what'),
#  (4, 'world the'),
#  (4, 'wonderland in'),
#  (4, "wonder 'i"),
#  (4, 'with associated'),
#  (4, 'who queen,'),
#  (4, 'what idea'),
#  (4, 'way which'),
#  (4, 'was what'),
#  (4, 'was queen'),
#  (4, 'voice a'),
#  (4, 'very replied'),
#  (4, 'ventured alice'),
#  (4, 'up getting'),
#  (4, 'tone, offended'),
#  (4, 'to way'),
#  (4, 'to was'),
#  (4, 'to ventured'),
#  (4, 'to sure'),
#  (4, 'to seems'),
#  (4, 'to is'),
#  (4, 'to her'),
#  (4, 'to glad'),
#  (4, 'to enough'),
#  (4, 'to donations'),
#  (4, 'to come'),
#  (4, 'to and'),
#  (4, 'time, this'),
#  (4, 'this, said'),
#  (4, 'this all'),
#  (4, 'think you'),
#  (4, 'think should'),
#  (4, 'things the'),
#  (4, 'thing a'),
#  (4, 'they then'),
#  (4, 'there that'),
#  (4, 'then, and'),
#  (4, 'their with'),
#  (4, 'the what'),
#  (4, "the that's"),
#  (4, 'the see'),
#  (4, 'the not'),
#  (4, 'the continued'),
#  (4, 'the change'),
#  (4, 'the before'),
#  (4, 'the be'),
#  (4, 'the after'),
#  (4, "the 'that's"),
#  (4, "that's 'and"),
#  (4, 'that was'),
#  (4, 'that think'),
#  (4, 'that know'),
#  (4, "sure i'm"),
#  (4, 'suppose i'),
#  (4, 'such is'),
#  (4, 'states. united'),
#  (4, 'states united'),
#  (4, 'spoke, he'),
#  (4, 'speak to'),
#  (4, 'sort a'),
#  (4, 'soon she'),
#  (4, 'soo--oop! beau--ootiful'),
#  (4, 'some with'),
#  (4, 'so be'),
#  (4, 'so and'),
#  (4, 'slates, their'),
#  (4, 'site web'),
#  (4, 'sister her'),
#  (4, 'side other'),
#  (4, 'she which'),
#  (4, 'she moment'),
#  (4, "shall 'i"),
#  (4, 'seemed who'),
#  (4, 'seemed there'),
#  (4, 'see could'),
#  (4, 'see and'),
#  (4, 'second the'),
#  (4, 'say you'),
#  (4, 'sat she'),
#  (4, "said you,'"),
#  (4, "said so,'"),
#  (4, "said majesty,'"),
#  (4, "said know,'"),
#  (4, 'round all'),
#  (4, 'rate any'),
#  (4, 'put she'),
#  (4, 'play to'),
#  (4, 'place the'),
#  (4, 'phrase the'),
#  (4, 'person the'),
#  (4, "pardon!' your"),
#  (4, 'over all'),
#  (4, 'out get'),
#  (4, 'or work'),
#  (4, 'only was'),
#  (4, 'only the'),
#  (4, 'one on'),
#  (4, 'one from'),
#  (4, 'on going'),
#  (4, 'offended an'),
#  (4, 'of queen'),
#  (4, 'of piece'),
#  (4, 'of part'),
#  (4, 'of opportunity'),
#  (4, 'of notice'),
#  (4, 'of mission'),
#  (4, 'of look'),
#  (4, 'of hold'),
#  (4, 'of heard'),
#  (4, 'of full'),
#  (4, 'of bottom'),
#  (4, 'of become'),
#  (4, 'now every'),
#  (4, 'nothing was'),
#  (4, 'not, would'),
#  (4, 'not, could'),
#  (4, 'new a'),
#  (4, 'never you'),
#  (4, 'nearly very'),
#  (4, 'my to'),
#  (4, "my 'in"),
#  (4, 'much too'),
#  (4, 'mouth its'),
#  (4, 'most the'),
#  (4, 'moment this'),
#  (4, 'moment a'),
#  (4, 'minutes few'),
#  (4, 'might you'),
#  (4, 'might she'),
#  (4, 'melancholy a'),
#  (4, 'me tell'),
#  (4, 'me make'),
#  (4, 'many so'),
#  (4, 'low, a'),
#  (4, 'looking and'),
#  (4, 'look the'),
#  (4, 'long as'),
#  (4, 'like you'),
#  (4, "like don't"),
#  (4, 'last this'),
#  (4, "know--' you"),
#  (4, "know didn't"),
#  (4, 'knew she'),
#  (4, 'just it'),
#  (4, 'jury, the'),
#  (4, 'join you'),
#  (4, "it?' is"),
#  (4, 'it, on'),
#  (4, 'it, for'),
#  (4, 'it when'),
#  (4, 'it is'),
#  (4, 'it found'),
#  (4, "it 'but"),
#  (4, 'is she'),
#  (4, "is 'it"),
#  (4, 'in that'),
#  (4, 'in her'),
#  (4, 'in began,'),
#  (4, 'in began'),
#  (4, 'in added'),
#  (4, 'idea no'),
#  (4, 'i why,'),
#  (4, 'i thing'),
#  (4, 'i dear!'),
#  (4, 'how see'),
#  (4, "how 'and"),
#  (4, 'hookah the'),
#  (4, 'her that'),
#  (4, 'hedgehog the'),
#  (4, 'heard never'),
#  (4, 'heads their'),
#  (4, "head!' her"),
#  (4, 'head its'),
#  (4, 'head his'),
#  (4, 'he when'),
#  (4, 'he that'),
#  (4, 'he but'),
#  (4, 'have shall'),
#  (4, 'hands, her'),
#  (4, 'had i'),
#  (4, 'gutenberg" "project'),
#  (4, 'grown had'),
#  (4, 'go would'),
#  (4, 'gave she'),
#  (4, 'gardeners three'),
#  (4, 'for opportunity'),
#  (4, 'for about'),
#  (4, 'footman the'),
#  (4, 'first at'),
#  (4, 'eyes her'),
#  (4, 'duchess; the'),
#  (4, 'duchess: the'),
#  (4, 'down looked'),
#  (4, 'do i'),
#  (4, 'distance, the'),
#  (4, "didn't 'i"),
#  (4, 'dance? the'),
#  (4, 'curious very'),
#  (4, 'course, of'),
#  (4, 'could. she'),
#  (4, 'changed been'),
#  (4, 'change to'),
#  (4, 'carroll lewis'),
#  (4, "can't 'i"),
#  (4, 'bottom the'),
#  (4, 'be shall'),
#  (4, 'be not'),
#  (4, 'be may'),
#  (4, 'be could'),
#  (4, 'be can'),
#  (4, 'back went'),
#  (4, 'back come'),
#  (4, 'at it'),
#  (4, 'at but'),
#  (4, 'as was'),
#  (4, 'as thing'),
#  (4, 'as might'),
#  (4, 'as herself,'),
#  (4, 'as alice'),
#  (4, 'as about'),
#  (4, 'are what'),
#  (4, 'any for'),
#  (4, 'any and'),
#  (4, 'and you,'),
#  (4, 'and volunteers'),
#  (4, 'and round'),
#  (4, 'and house,'),
#  (4, 'and her,'),
#  (4, 'and gryphon,'),
#  (4, 'and down,'),
#  (4, 'and before,'),
#  (4, 'and about,'),
#  (4, "all that's"),
#  (4, 'alice cried'),
#  (4, 'air. the'),
#  (4, 'agree you'),
#  (4, "afraid 'i'm"),
#  (4, 'a you'),
#  (4, 'a than'),
#  (4, 'a provide'),
#  (4, 'a out'),
#  (4, 'a only'),
#  (4, 'a made'),
#  (4, 'a gave'),
#  (4, 'a felt'),
#  (4, 'a down'),
#  (4, "'well, caterpillar."),
#  (4, "'i'm alice."),
#  (4, "'i alice;"),
#  (4, '"project phrase'),
#  (3, "youth,' my"),
#  (3, 'youth, the'),
#  (3, 'your to'),
#  (3, 'your in'),
#  (3, "your 'hold"),
#  (3, "your 'give"),
#  (3, 'young the'),
#  (3, "you're what"),
#  (3, 'you which'),
#  (3, 'you unless'),
#  (3, 'you is,'),
#  (3, 'you for,'),
#  (3, 'you course'),
#  (3, 'you agreement,'),
#  (3, "you 'oh,"),
#  (3, "you 'did"),
#  (3, "you 'are"),
#  (3, 'writing in'),
#  (3, 'write to'),
#  (3, 'would that'),
#  (3, 'would not,'),
#  (3, 'works. electronic'),
#  (3, 'works, electronic'),
#  (3, 'works gutenberg-tm'),
#  (3, 'work, electronic'),
#  (3, 'wonderland, in'),
#  (3, "wonder?' i"),
#  (3, "won't 'i"),
#  (3, 'with time'),
#  (3, 'with them'),
#  (3, 'with posted'),
#  (3, 'with over'),
#  (3, 'with on'),
#  (3, 'with in'),
#  (3, 'with down'),
#  (3, 'with complying'),
#  (3, 'with begins'),
#  (3, 'with and'),
#  (3, 'wish only'),
#  (3, 'will i'),
#  (3, 'will dance?'),
#  (3, 'which in'),
#  (3, 'what out'),
#  (3, "what 'but"),
#  (3, "what 'and"),
#  (3, 'were who'),
#  (3, 'were these'),
#  (3, 'were eyes'),
#  (3, 'went turtle'),
#  (3, 'went hatter'),
#  (3, 'went gryphon'),
#  (3, 'well very'),
#  (3, 'way little'),
#  (3, 'way her'),
#  (3, "was,' it"),
#  (3, 'was, it'),
#  (3, 'was, argument'),
#  (3, 'was thing'),
#  (3, 'was mouse'),
#  (3, 'was hatter'),
#  (3, 'was (she'),
#  (3, 'was (it'),
#  (3, 'want you'),
#  (3, "want don't"),
#  (3, 'walked and'),
#  (3, 'waited she'),
#  ...]

# %% [markdown]
# ### Problem 4. ArgMax and ArgSort

# %% [markdown]
# >**(a)** Finding the index of the largest (or smallest) element in a list is a commonly needed opera-
# tion, but Python does not provide this function in its standard library (numpy will provide those). Write two functions

# %%
def argmax(list_input):
    last_num = list_input[0]
    last_ind = 0
    for index, num in enumerate(list_input):
        if num > last_num:
            last_num = num
            last_ind = index
    print(last_ind)
    
def argmin(list_input):
    last_num = list_input[0]
    last_ind = 0
    for index, num in enumerate(list_input):
        if num < last_num:
            last_num = num
            last_ind = index
    print(last_ind)

# %% [markdown]
# >that return the index of the largest and smallest element in the list *list_input* respectively. Example output:

# %% [markdown]
#     >>> list1 = [1,3,2,6,0,2,3,4,5]
#     >>> argmax(list1)
#     3
#     >>> argmin(list1)
#     4

# %%
# try it here
list1 = [1,3,2,6,0,2,3,4,5]
argmax(list1)
argmin(list1)
# Out:
# 3
# 4

# %% [markdown]
# >**(b)** **(extra)** Instead of just finding the index of the largest or smallest element, one might be interested in the entire list of indices that would sort the list. In one of the previous exercises we presented you with this piece of code for finding the indices that sort a list.

# %%
l = [1,3,2,6,0,2,3,4,5]
zip(*sorted(zip(l, range(len(l)))))[1]
# Out:
# (4, 0, 2, 5, 1, 6, 7, 8, 3)

# %% [markdown]
# >It works by combining the list with the list of indices, sorting the combined list, and then untangling the results. Have a look at the documentation of the *zip* function to understand how it works. Write a function:

# %%
def argsort(l):
    return zip(*sorted(zip(l, range(len(l)))))[1]

# %% [markdown]
# >that returns the list of indices that would sort the list, but instead of using the hard to read
# line above that uses zip, use list comprehensions. Example output:

# %% [markdown]
#     >>> l = [1,3,2,6,0,2,3,4,5]
#     >>> argsort(l)
#     [4, 0, 2, 5, 1, 6, 7, 8, 3]
#     >>> [l[i] for i in argsort(l)]
#     [0, 1, 2, 2, 3, 3, 4, 5, 6]

# %%
# try it here
l = [1,3,2,6,0,2,3,4,5]
print argsort(l)
print [l[i] for i in argsort(l)]
# Out:
# (4, 0, 2, 5, 1, 6, 7, 8, 3)
# [0, 1, 2, 2, 3, 3, 4, 5, 6]

# %% [markdown]
# ### Problem 5. Simple ciphers

# %% [markdown]
# Suppose you wish to send your friend a message, and if someone happens to look at it, you do not want them to know what it says.<br>
# A simple way of doing this is to replace each letter, with
# a different one.<br>
# For example, suppose I wish to send the phrase “dancing is silent poetry”.<br>
# By exchanging each letter with another, we can encode this as: “robqwbu wg gwzsbh dcshfm”.

# %% [markdown]
# >**(a)** Write a function that swaps the letter in a string according to a dictionary. For example:

# %%
def swapdict(string, dic):
    str_len = len(string)
    output = ''
    for i in range(str_len):
        if string[i] in dic:
            output += str(dic[string[i]])
            #print dic[string[i]]
        else:
            output += string[i]
            #print string[i]
    
    return (output)

# %% [markdown]
#     >>> print swapdict('hello', {'e': 'i'})
#     hillo
#     >>> print swapdict('hello', {'l': 'w'})
#     hewwo
#     >>> print swapdict('hello', {'l': 'm', 'h': 'p', 'e': 'o', 'o': 'e'})
#     pomme

# %%
# your code here
print swapdict('hello', {'e': 'i'})
# Out:
# hillo

# %% [markdown]
# >**(b)** Write a function that generates a dictionary whose keys are letters of the alphabet, and whose values are those letters shifted along by a given number of letters.

# %%
def shiftdict(i):
    from string import ascii_lowercase
    key_list = list(ascii_lowercase)
    val_list = []

    #i=3

    for index, ref in enumerate(key_list):
        if i + index > 25:

            val_list.append(key_list[((i + index)-26)])
            #print key_list[(i + index)-26]
        else:
            val_list.append(key_list[(i + index)])
            #print key_list[(i + index)]

    t = zip(key_list, val_list)

    #print t

    otp_dict = dict((y, x) for y, x in t)
    return otp_dict

# %% [markdown]
#     >>> print shiftdict(0)
#     {'a': 'a', 'b': 'b', ..., 'z': 'z'}
#     >>> print shiftdict(3)
#     {'a': 'd', 'b': 'e', ..., 'z': 'c'}
#     >>> print shiftdict(13)
#     {'a': 'n', 'b': 'o', ..., 'z': 'm'}

# %% [markdown]
# >In the first case, the letters are not shifted, because the argument to *shiftdict* is zero. In the second case, letters are shifted along by three letters: “a” is the first letter, and “d” is the forth letter, and so key “a” points to letter “d”.

# %%
# try it here
print shiftdict(3)
# Out:
# {'a': 'd', 'c': 'f', 'b': 'e', 'e': 'h', 'd': 'g', 'g': 'j', 'f': 'i', 'i': 'l', 'h': 'k', 'k': 'n', 'j': 'm', 'm': 'p', 'l': 'o', 'o': 'r', 'n': 'q', 'q': 't', 'p': 's', 's': 'v', 'r': 'u', 'u': 'x', 't': 'w', 'w': 'z', 'v': 'y', 'y': 'b', 'x': 'a', 'z': 'c'}

# %% [markdown]
# >**(c)** Now we are ready to encode our message: “dancing is silent poetry”.

# %% [markdown]
#     >>> print swapdict('dancing is silent poetry', shiftdict(14))

# %%
print(swapdict('dancing is silent poetry', shiftdict(14)))
# Out:
# robqwbu wg gwzsbh dcshfm

# %% [markdown]
# >Check that it matches the encoding given above.

# %% [markdown]
# >**(d)** Write a function that takes a dictionary and swaps the roles of the keys and the values.

# %%
def invertdict(dictionary):
    #dictionary = {'a': 'b', 'b': 'c', 'c': 'd'}
    a=[]
    b=[]

    print(dictionary)

    for x,y in dictionary.items():
        a.append(y)
        b.append(x)

    t = zip(a, b)

        #print t

    otp_dict = dict((y, x) for y, x in t)
    #print(dict)
    return otp_dict

invertdict({'a': 'b', 'b': 'c', 'c': 'd'})
# Out:
# {'a': 'b', 'c': 'd', 'b': 'c'}
# {'b': 'a', 'c': 'b', 'd': 'c'}

# %% [markdown]
# Here are some examples to check it works:

# %% [markdown]
#     >>> invertdict({'a':'b'})
#     {'b': 'a'}
#     >>> invertdict({'b':'a', 'a': 'b'})
#     {'a': 'b', 'b': 'a'}
#     >>> invertdict({'a':'b', 'b': 'c', 'c': 'a'})
#     {'a': 'c', 'b': 'a','c': 'b'}

# %%
invertdict({'a':'b'})
# Out:
# {'a': 'b'}
# {'b': 'a'}

# %% [markdown]
# >**(e)** Can you decode this message, that was encoded using the same scheme? “qzuipo nblft ju tjnqmf ipqfgvmmz”. Use only *invertdict*, *swapdict* and *shiftdict*.

# %%
print(swapdict('qzuipo nblft ju tjnqmf ipqfgvmmz', invert(shiftdict(-14))))



#print(swapdict('qzuipo nblft ju tjnqmf ipqfgvmmz', invertdict(shiftdict(-14))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-300-153de2e74c9b> in <module>()
# ----> 1 print(swapdict('qzuipo nblft ju tjnqmf ipqfgvmmz', invert(shiftdict(-14))))
#       2
#       3 #print(swapdict('qzuipo nblft ju tjnqmf ipqfgvmmz', invertdict(shiftdict(-14))))
#
# NameError: name 'invert' is not defined

# %% [markdown]
# >**(f)** You notice that your friend is sending encrypted messages to other people, but they appear to be encoded using a different argument to shiftdict.<br>
# Use a for-loop, swapdict and shiftdict to work out the encoding scheme, and what this message says: “nyhcpaf pz aol yvva vm spnoaulzz”.

# %%
# your code here
